# %% [markdown]
# ## Read in all the setlist datasets

# %%
import pandas as pd
import glob
import os
import fuzzy_pandas as fpd
import numpy as np


path = '/Users/jonzimmerman/Desktop/Data Projects/Setlists/data/setlists/ideal_setlists/'
all_files = glob.glob(os.path.join(path, "*.csv"))

ideal_setlists = pd.concat((pd.read_csv(f) for f in all_files), ignore_index=True)
ideal_setlists.shape
# Out:
# (774, 9)

# %%
round2 = ['Florence + the Machine','Little Dragon', 'Passion Pit', 'Lord Huron']
round3 = ['Tame Impala']
ideal_setlists = ideal_setlists[ideal_setlists['Artist Name'].isin(round3)]
ideal_setlists['Artist Name'].unique()
# Out:
# array(['Tame Impala'], dtype=object)

# %%
ideal_setlists.head()
# Out:
#                 Song Name  Closeness Score  Happy Score  Angry Score  \
# 48               elephant              0.0         0.13         0.07
# 49      solitude is bliss              0.0         0.39         0.00
# 50          mind mischief              0.0         0.27         0.06
# 51         cause im a man              0.0         0.25         0.04
# 52  it is not meant to be              0.0         0.25         0.00
#
#     Sad Score  Surprise Score  Fear Score Prioritized Emotion  Artist Name
# 48       0.40            0.20        0.20               Happy  Tame Impala
# 49       0.18            0.18        0.25               Happy  Tame Impala
# 50       0.06            0.33        0.27               Happy  Tame Impala
# 51       0.33            0.08        0.29               Happy  Tame Impala
# 52       0.29            0.17        0.29               Happy  Tame Impala

# %%
ideal_setlists['Prioritized Emotion'].unique()
# Out:
# array(['Happy', 'Surprise', 'Fear', 'Angry', 'Sad', nan], dtype=object)

# %%
ideal_setlists[(ideal_setlists['Artist Name']=="Passion Pit") & (ideal_setlists['Prioritized Emotion'].isna())]
# Out:
#                             Song Name  Closeness Score  Happy Score  \
# 269                   where we belong            0.130         0.14
# 270                       the reeling            0.120         0.17
# 271                      carried away            0.110         0.09
# 272                     better things            0.190         0.04
# 273  my brother taught me how to swim            0.230         0.11
# 274                  whole life story            0.160         0.03
# 275            constant conversations            0.230         0.20
# 276                   to kingdom come            0.165         0.02
# 277                    ill be alright            0.240         0.15
# 278                          hideaway            0.170         0.21
# 279                       take a walk            0.270         0.10
# 280                   looks like rain            0.325         0.10
# 281                            dreams            0.240         0.12
#
#      Angry Score  Sad Score  Surprise Score  Fear Score Prioritized Emotion  \
# 269         0.11       0.25            0.18        0.32                 NaN
# 270         0.08       0.17            0.21        0.38                 NaN
# 271         0.15       0.38            0.12        0.25                 NaN
# 272         0.12       0.24            0.29        0.31                 NaN
# 273         0.15       0.35            0.20        0.19                 NaN
# 274         0.10       0.41            0.21        0.24                 NaN
# 275         0.03       0.31            0.11        0.34                 NaN
# 276         0.11       0.41            0.22        0.24                 NaN
# 277         0.19       0.33            0.04        0.30                 NaN
# 278         0.12       0.21            0.12        0.33                 NaN
# 279         0.18       0.26            0.10        0.36                 NaN
# 280         0.29       0.24            0.14        0.24                 NaN
# 281         0.00       0.38            0.25        0.25                 NaN
#
#      Artist Name
# 269  Passion Pit
# 270  Passion Pit
# 271  Passion Pit
# 272  Passion Pit
# 273  Passion Pit
# 274  Passion Pit
# 275  Passion Pit
# 276  Passion Pit
# 277  Passion Pit
# 278  Passion Pit
# 279  Passion Pit
# 280  Passion Pit
# 281  Passion Pit

# %% [markdown]
# ## Read in all the album datasets

# %%
path = '/Users/jonzimmerman/Desktop/Data Projects/Setlists/data/albums/'
all_files = glob.glob(os.path.join(path, "*.xlsx"))

albums = pd.concat((pd.read_excel(f) for f in all_files), ignore_index=True)
albums.shape
# Out:
# (664, 3)

# %%
round2 = ['Little Dragon', 'Florence + the Machine', 'Lord Huron', 'Passion Pit']
round3 = ['Tame Impala']
albums = albums[albums['artist'].isin(round3)]
albums['artist'].value_counts()
# Out:
# artist
# Tame Impala    48
# Name: count, dtype: int64

# %% [markdown]
# ## Join albums data onto setlists data

# %%
ideal_setlists
# Out:
#                       Song Name  Closeness Score  Happy Score  Angry Score  \
# 48                     elephant            0.000         0.13         0.07
# 49            solitude is bliss            0.000         0.39         0.00
# 50                mind mischief            0.000         0.27         0.06
# 51               cause im a man            0.000         0.25         0.04
# 52        it is not meant to be            0.000         0.25         0.00
# ..                          ...              ...          ...          ...
# 628  the less i know the better            0.270         0.22         0.04
# 629                    patience            0.320         0.09         0.05
# 630                    lucidity            0.305         0.08         0.23
# 631              cause im a man            0.320         0.25         0.04
# 632                    on track            0.310         0.14         0.06
#
#      Sad Score  Surprise Score  Fear Score Prioritized Emotion  Artist Name
# 48        0.40            0.20        0.20               Happy  Tame Impala
# 49        0.18            0.18        0.25               Happy  Tame Impala
# 50        0.06            0.33        0.27               Happy  Tame Impala
# 51        0.33            0.08        0.29               Happy  Tame Impala
# 52        0.29            0.17        0.29               Happy  Tame Impala
# ..         ...             ...         ...                 ...          ...
# 628       0.19            0.33        0.22                 NaN  Tame Impala
# 629       0.23            0.23        0.41                 NaN  Tame Impala
# 630       0.23            0.15        0.31                 NaN  Tame Impala
# 631       0.33            0.08        0.29                 NaN  Tame Impala
# 632       0.28            0.08        0.44                 NaN  Tame Impala
#
# [78 rows x 9 columns]

# %%
albums
# Out:
#                       album                                   song  \
# 0             Little Dragon                                  Twice
# 1             Little Dragon                              Turn Left
# 2             Little Dragon                                No Love
# 3             Little Dragon                         Recommendation
# 4             Little Dragon                     Constant Surprises
# ..                      ...                                    ...
# 611  Tremendous Sea of Love                            I'm Perfect
# 612  Tremendous Sea of Love                     You Have the Right
# 613  Tremendous Sea of Love                         Inner Dialogue
# 614  Tremendous Sea of Love                               Undertow
# 615  Tremendous Sea of Love  For Sondra (It Means the World to Me)
#
#             artist
# 0    Little Dragon
# 1    Little Dragon
# 2    Little Dragon
# 3    Little Dragon
# 4    Little Dragon
# ..             ...
# 611    Passion Pit
# 612    Passion Pit
# 613    Passion Pit
# 614    Passion Pit
# 615    Passion Pit
#
# [234 rows x 3 columns]

# %%
full_df = fpd.fuzzy_merge(ideal_setlists, albums,
            left_on=['Artist Name','Song Name'],
            right_on=['artist','song'],
            method='levenshtein',
            threshold=0.7,
            join = 'left-outer',
            keep = 'all'
            )

full_df = full_df.drop(columns=['artist', 'song'])
print('Before: ',ideal_setlists.shape[0])
print('After:', full_df.shape[0])
# Out:
# Before:  78
# After: 78

# %% [markdown]
# ## Label non-prioritized subsets as 'None'

# %%
full_df['Prioritized Emotion'] = full_df['Prioritized Emotion'].fillna('None')
full_df['Prioritized Emotion'].value_counts()
# Out:
# Prioritized Emotion
# Happy       13
# Surprise    13
# Fear        13
# Angry       13
# Sad         13
# None        13
# Name: count, dtype: int64

# %%
missing_albums = full_df[full_df['album']==''][['Artist Name','Song Name']]
missing_albums[missing_albums['Artist Name'] == "Tame Impala"]
# Out:
#     Artist Name                                 Song Name
# 65  Tame Impala                          sundown syndrome
# 66  Tame Impala                                  patience
# 67  Tame Impala                                  patience
# 68  Tame Impala                          sundown syndrome
# 69  Tame Impala  forty one mosquitoes flying in formation
# 70  Tame Impala                   half full glass of wine
# 71  Tame Impala  forty one mosquitoes flying in formation
# 72  Tame Impala                                  patience
# 73  Tame Impala                          sundown syndrome
# 74  Tame Impala  forty one mosquitoes flying in formation
# 75  Tame Impala                                  patience
# 76  Tame Impala                          sundown syndrome
# 77  Tame Impala                                  patience

# %% [markdown]
# ## Spruce up some of the artist-song combinations

# %%
full_df['album'] = np.where(full_df['Song Name']=='i lied', 'Long Lost', full_df['album'])
full_df['album'] = np.where(full_df['Song Name']=='we went wild', 'NA', full_df['album'])
full_df['album'] = np.where(full_df['Song Name']=='the problem with your daughter', 'NA', full_df['album'])
full_df['album'] = np.where(full_df['Song Name']=='your other life', 'Long Lost', full_df['album'])
full_df['album'] = np.where(full_df['Song Name']=='son of a gun', 'NA', full_df['album'])

full_df['album'] = np.where(full_df['Song Name']=='dont cry', 'Season High', full_df['album'])
full_df['album'] = np.where(full_df['Song Name']=='a new', 'Machine Dreams', full_df['album'])


full_df['album'] = np.where(full_df['Song Name']=='american blood', 'Gossamer', full_df['album'])
full_df['album'] = np.where(full_df['Song Name']=='better things', 'NA', full_df['album'])
full_df['album'] = np.where(full_df['Song Name']=='dreams', 'Manners', full_df['album'])
full_df['album'] = np.where(full_df['Song Name']=='cuddle fuddle', 'NA', full_df['album'])
full_df['album'] = np.where(full_df['Song Name']=='smile upon me', 'NA', full_df['album'])

full_df['album'] = np.where(full_df['Song Name']=='mermaids', 'Dance Fever', full_df['album'])
full_df['album'] = np.where(full_df['Song Name']=='st jude', 'How Big, How Blue, How Beautiful', full_df['album'])
full_df['album'] = np.where(full_df['Song Name']=='flakes', 'Lungs', full_df['album'])
full_df['album'] = np.where(full_df['Song Name']=='if i had a heart', 'NA', full_df['album'])
full_df['album'] = np.where(full_df['Song Name']=='only love can break your heart', 'NA', full_df['album'])
full_df['album'] = np.where(full_df['Song Name']=='falling', 'Lungs', full_df['album'])
full_df['album'] = np.where(full_df['Song Name']=='are you hurting the one you love', 'Lungs', full_df['album'])
full_df['album'] = np.where(full_df['Song Name']=='bedroom hymns', 'Ceremonials', full_df['album'])

# %% [markdown]
# ## Join lyrics back on to full_df

# %%
path = '/Users/jonzimmerman/Desktop/Data Projects/Setlists/data/lyrics/'
lyrics = pd.read_csv(path + 'lyrics_cleaned_final_2024-05-29.csv')
lyrics.shape
# Out:
# (1150, 12)

# %%
lyrics = lyrics[['artist','title','cleaned_lyrics']]

full_df_lyrics = fpd.fuzzy_merge(
    full_df, 
    lyrics,
    left_on=['Artist Name','Song Name'],
    right_on=['artist','title'],
    method='levenshtein',
    threshold=0.6,
    join = 'left-outer'
)

full_df_lyrics = full_df_lyrics.drop(columns=['artist', 'title'])
print('Before:',full_df.shape)
print('After:',full_df_lyrics.shape)
# Out:
# Before: (78, 10)
# After: (170, 11)

# %% [markdown]
# ### Remove duplicates that were created in process

# %%
dup_df_lyrics = full_df_lyrics
full_df_lyrics = full_df_lyrics.drop_duplicates(keep='first')

print('Before: ',dup_df_lyrics.shape[0])
print('After: ',full_df_lyrics.shape[0])
# Out:
# Before:  170
# After:  85

# %%
full_df_lyrics.head()
# Out:
#                Song Name  Closeness Score  Happy Score  Angry Score  \
# 0               elephant              0.0         0.13         0.07
# 2      solitude is bliss              0.0         0.39         0.00
# 4          mind mischief              0.0         0.27         0.06
# 6         cause im a man              0.0         0.25         0.04
# 8  it is not meant to be              0.0         0.25         0.00
#
#    Sad Score  Surprise Score  Fear Score Prioritized Emotion  Artist Name  \
# 0       0.40            0.20        0.20               Happy  Tame Impala
# 2       0.18            0.18        0.25               Happy  Tame Impala
# 4       0.06            0.33        0.27               Happy  Tame Impala
# 6       0.33            0.08        0.29               Happy  Tame Impala
# 8       0.29            0.17        0.29               Happy  Tame Impala
#
#           album                                     cleaned_lyrics
# 0      Lonerism  well he feels like an elephant shaking his big...
# 2  Innerspeaker  cracks in the pavement underneath my shoe i ca...
# 4      Lonerism  feels like my life is ready to blow me and my ...
# 6      Currents  like the brutal morning sun it dawns on me wha...
# 8  Innerspeaker  i wanted her i wanted her but she doesnt like ...

# %%
#### Create matrix of counts
contingency_table = pd.crosstab(full_df_lyrics['Artist Name'], full_df_lyrics['Prioritized Emotion'])
contingency_table
# Out:
# Prioritized Emotion  Angry  Fear  Happy  None  Sad  Surprise
# Artist Name
# Tame Impala             15    14     14    14   14        14

# %%
full_df_lyrics.to_csv('full_df_lyrics_round3.csv',index=False)

# %% [markdown]
# ## Inspect Setlists with extra songs

# %%
full_df_lyrics[(full_df_lyrics['Artist Name']=="Florence + the Machine") & (full_df_lyrics['Prioritized Emotion']=="Angry")]
# Out:
#                           Song Name  Closeness Score  Happy Score  \
# 283                   ship to wreck             0.00         0.11
# 284                       100 years             0.00         0.09
# 285                   breaking down             0.00         0.07
# 286                   leave my body             0.00         0.02
# 287                  lover to lover             0.00         0.20
# 288      rabbit heart (raise it up)             0.00         0.07
# 289                 never let me go             0.01         0.15
# 290                   drumming song             0.00         0.00
# 291          what the water gave me             0.01         0.14
# 292          what the water gave me             0.01         0.14
# 293                          hunger             0.00         0.15
# 294                            free             0.00         0.20
# 432                        mermaids             0.00         0.32
# 433  only love can break your heart             0.00         0.30
#
#      Angry Score  Sad Score  Surprise Score  Fear Score Prioritized Emotion  \
# 283         0.03       0.51            0.18        0.17               Angry
# 284         0.04       0.39            0.15        0.33               Angry
# 285         0.04       0.21            0.50        0.18               Angry
# 286         0.06       0.33            0.27        0.31               Angry
# 287         0.07       0.23            0.30        0.20               Angry
# 288         0.07       0.23            0.37        0.27               Angry
# 289         0.05       0.20            0.27        0.34               Angry
# 290         0.07       0.20            0.28        0.44               Angry
# 291         0.05       0.33            0.19        0.29               Angry
# 292         0.05       0.33            0.19        0.29               Angry
# 293         0.04       0.13            0.50        0.17               Angry
# 294         0.07       0.30            0.14        0.30               Angry
# 432         0.08       0.19            0.19        0.22               Angry
# 433         0.07       0.30            0.22        0.11               Angry
#
#                 Artist Name                             album  \
# 283  Florence + the Machine  How Big, How Blue, How Beautiful
# 284  Florence + the Machine                      High as Hope
# 285  Florence + the Machine                       Ceremonials
# 286  Florence + the Machine                       Ceremonials
# 287  Florence + the Machine                       Ceremonials
# 288  Florence + the Machine                             Lungs
# 289  Florence + the Machine                       Ceremonials
# 290  Florence + the Machine                             Lungs
# 291  Florence + the Machine                       Ceremonials
# 292  Florence + the Machine                       Ceremonials
# 293  Florence + the Machine                      High as Hope
# 294  Florence + the Machine                       Dance Fever
# 432  Florence + the Machine                       Dance Fever
# 433  Florence + the Machine                                NA
#
#                                         cleaned_lyrics
# 283  dont touch the sleeping pills they mess with m...
# 284  i believe in you and in our hearts we know the...
# 285  all alone it was always there you see and even...
# 286  im gonna be released from behind these lines a...
# 287  ive been losing sleep ive been keeping myself ...
# 288  the looking glass so shiny and new how quickly...
# 289  looking up from underneath fractured moonlight...
# 290  theres a drumming noise inside my head that st...
# 291  time it took us to where the water was that’s ...
# 292  time it took us to where the water was thats w...
# 293  ooh ooh ooh ooh ooh ooh ooh ooh ooh ooh ooh oo...
# 294  sometimes i wonder if i should be medicated if...
# 432  i thought that i was hungry for love maybe i w...
# 433  when you were young and on your own how did it...

# %%
full_df_lyrics.to_csv('full_df_lyrics.csv')

# %% [markdown]
# ## Which songs don't have lyrics?

# %%
full_df_lyrics[full_df_lyrics['cleaned_lyrics']=='']['Song Name'].value_counts()
# Out:
# Series([], Name: count, dtype: int64)

# %%
song = lyrics[lyrics['title'].str.contains('if i had a heart', case = False, na = False)].head(1)

song = song.rename(
    columns={'title': 'Song Name', 
             'artist': 'Artist Name'}
)

insert = song['cleaned_lyrics'].values[0]
insert
# Out:
# 'if i had a voice i would voice i would say id promise you the stars up above you promise you my gold diamond ring and we sing oooh ooh ohh oh oh ohhhh ohh oh oh and we sing oooh ooh ohh oh oh ohhhh ohh oh it seems that i had been held in some dreaming state a tourist in the waking world never quite awake and no kiss no gentle word can wake me from this slumber until i realized that it was you who held me under felt it in my fist in my feet in the hollows of my eyelids shaking through my skull through my spine and down through my ribs no more dreaming the dead as if death itself was undone no more calling like a crow for a boy for a body in the garden no calling like a crow so in love so in love no more dreaming like a girl so in love so in love no more dreaming like a girl so in love with with the wrong world and i could here the thunder and see the lightening crack and all around the world was waking i never could go back cause all the walls of dreaming they were torn wide open and finally it seems that the spell was broken and all my bones began to shake my eyes flew open and all my bones began to shake my eyes flew open no more dreaming the dead as if death itself was undone no more calling like a crow for a boy for a body in the garden no more dreaming like a girl so in love so in love no more dreaming like a girl so in love so in love no more dreaming like a girl so in love with with the wrong world snow white stitching up the circuit board synapse slipping through the hidden door snow white stitching up the circuit board no more dreaming the dead as if death itself was undone no more calling like a crow for a boy for a body in the garden no more dreaming like a girl so in love so in love no more dreaming like a girl so in love so in love no more dreaming like a girl so in love with with the wrong world snow white stitching up the circuit board synapse slipping through the hidden door snow white stitching up the circuit board synapse slipping'

# %% [markdown]
# ### Add lyrics back in

# %%
full_df_lyrics[full_df_lyrics['Song Name']=="if i had a heart"]
# Out:
#             Song Name  Closeness Score  Happy Score  Angry Score  Sad Score  \
# 452  if i had a heart             0.19         0.26         0.09       0.16
# 453  if i had a heart             0.02         0.26         0.09       0.16
# 454  if i had a heart             0.00         0.26         0.09       0.16
#
#      Surprise Score  Fear Score Prioritized Emotion             Artist Name  \
# 452            0.19        0.31                None  Florence + the Machine
# 453            0.19        0.31                 Sad  Florence + the Machine
# 454            0.19        0.31            Surprise  Florence + the Machine
#
#     album cleaned_lyrics
# 452    NA
# 453    NA
# 454    NA

# %%
full_df_lyrics['cleaned_lyrics'] = np.where(full_df_lyrics['Song Name']=="5/4", insert, full_df_lyrics['cleaned_lyrics'])
# Out:
# /var/folders/yr/521qh_vn01n7j762jny9bmhw0000gn/T/ipykernel_15018/3607645642.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   full_df_lyrics['cleaned_lyrics'] = np.where(full_df_lyrics['Song Name']=="5/4", insert, full_df_lyrics['cleaned_lyrics'])
